# %%
import numpy as np
import twitter,re, datetime
import pandas as pd

# %%
twitter_keys = {
    'consumer_key':        'L4sziHBqV4VUIfKezbos0JMVl',
    'consumer_secret':     'lJau6R7GIHFwoGR5wB3PlLQPXBChwzJFJ9WGXXtazcDSA1Vb1X',
    'access_token_key':    '941359629606539264-05XcmQfdwMXTbPNWS3r7cZThvbQBxCK',
    'access_token_secret': 'VdE3VJVk6oxbohQGcw7WYA5Tg4Sr8kW9duTO1wxmB6qXk'
}

# %%
api = twitter.Api(
    consumer_key         =   twitter_keys['consumer_key'],
    consumer_secret      =   twitter_keys['consumer_secret'],
    access_token_key     =   twitter_keys['access_token_key'],
    access_token_secret  =   twitter_keys['access_token_secret'],
    tweet_mode = 'extended'
)

# %%
type(api)
# Out:
# twitter.api.Api

# %% [markdown]
# #### using GetUserTimeline method of twitter.api.Api object to get tweet text and tweet details for a user
# #### max count is 200

# %%
x = api.GetUserTimeline(screen_name = "HillaryClinton", count=20,include_rts=False)
x = [_.AsDict() for _ in x]

# %%
x[0]
# Out:
# {'created_at': 'Mon May 20 21:11:11 +0000 2019',
#  'favorite_count': 24485,
#  'full_text': 'This is grotesque. https://t.co/CvFf9rPO2H',
#  'hashtags': [],
#  'id': 1130581759639396352,
#  'id_str': '1130581759639396352',
#  'lang': 'en',
#  'retweet_count': 5952,
#  'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#  'urls': [{'expanded_url': 'https://www.nytimes.com/2019/05/18/us/trump-pardons-war-crimes.html',
#    'url': 'https://t.co/CvFf9rPO2H'}],
#  'user': {'created_at': 'Tue Apr 09 18:04:35 +0000 2013',
#   'description': '2016 Democratic Nominee, SecState, Senator, hair icon. Mom, Wife, Grandma x2, lawyer, advocate, fan of walks in the woods & standing up for our democracy.',
#   'favourites_count': 1125,
#   'followers_count': 24544845,
#   'friends_count': 796,
#   'id': 1339835893,
#   'id_str': '1339835893',
#   'lang': 'en',
#   'listed_count': 42117,
#   'location': 'New York, NY',
#   'name': 'Hillary Clinton',
#   'profile_background_color': '0057B8',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1339835893/1539631689',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1051914952192057344/xwZDe7zt_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1051914952192057344/xwZDe7zt_normal.jpg',
#   'profile_link_color': '0057B8',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '000000',
#   'profile_text_color': '000000',
#   'screen_name': 'HillaryClinton',
#   'statuses_count': 10919,
#   'url': 'https://t.co/99DVW9q1yt',
#   'verified': True},
#  'user_mentions': []}

# %%
# printing all tweets' id and text
for element in x:
    print (element['id'])
    print (element['full_text'])
    print('-----')
# Out:
# 1130581759639396352
# This is grotesque. https://t.co/CvFf9rPO2H
# -----
# 1130573037420597249
# In the face of extreme abortion bans sweeping the country, we all have to stand up for women's rights.
#
# At noon tomorrow, join @PPAct, @NARAL, @OnwardTogether partner @IndivisibleTeam, and other groups to #StopTheBans.
#
# Find an event near you: https://t.co/pE5pfz5tiA
# -----
# 1130555721416888320
# The boy is the second child to have died in CBP custody in the past week. https://t.co/uLJVezJ1SE
# -----
# 1129433708807770112
# Watching the mayor’s race in Denver and pulling for @MayorHancock—he’s a proven progressive leader who will work hard for Colorado.
# -----
# 1129421840500363264
# In 2019, every day is Endangered Species Day. We have to act now to prevent the loss of 1 million species over the next few decades—losses that would have a profound effect on human beings. https://t.co/lSxGmUVOXL
# -----
# 1129405238534901761
# More than 200 major corporations, 500 statewide and local organizations, a bipartisan consensus in Congress, and 70% of Americans support legislation protecting LGBTQ people from discrimination.
#
# I am proud to stand with them and the other @HRC to support the #EqualityAct.
# -----
# 1129387825252712449
# As I said in my keynote celebrating the essential work of @heartlandhelps: We have to affirm that torture, physical and psychological, is wrong and will not be tolerated—whether it happens in a prison in Syria or in a cage on our southern border. https://t.co/s8MVpdzgwf
# -----
# 1129027398920491009
# Grateful to Planned Parenthood for continuing to provide essential services in Alabama and elsewhere while helping to fight the state legislative bans on women’s human and constitutional rights. https://t.co/oMgHvgaP0d
# -----
# 1128716614990487552
# If you want to be inspired every day, I highly recommend giving our partners a follow: @alliance4youth @arenasummit @CollectivePAC @colorofchange @domesticworkers @emergeamerica @IndivisibleTeam @iVoteFund @latinovictoryUS @runforsomething @swingleft @votolatino @WeDemandJustice
# -----
# 1128716614256427008
# We’ve raised money to reunite families separated at the border and brought in $12 million for progressive groups, candidates, &amp; committees during the 2018 elections.
#
# There’s so much to be proud of. I hope you’ll take a moment this week to reflect on how far we’ve come together.
# -----
# 1128716613463814145
# Happy two-year anniversary to our @OnwardTogether partners. In two years, we’ve brought on 13 incredible groups as official partners and supported many more through grants.
# -----
# 1128668280913387521
# None of us should accept a future in which our daughters and granddaughters have fewer rights than we do.
#
# Choose a way to help, ask a friend to join you, and let's get to work.
# -----
# 1128668142018924545
# Here's what you can do today to fight back:
#
# 1. Donate to @abortionfunds: https://t.co/JY9MwWRG6g
#
# 2. Support @EmergeAmerica, @EMILYSList, @runforsomething, and @TheDLCC, who work to elect pro-choice candidates
#
# 3. Join @supermajority to organize for the future
# -----
# 1128667204164169728
# The abortion bans in Alabama, Georgia, Ohio, Kentucky, and Mississippi are appalling attacks on women's lives and fundamental freedoms.
#
# Women's rights are human rights.
#
# We will not go back.
# -----
# 1128320182194192384
# As I told @Columbia students last night:
#
# For all the progress we've made on civil rights and women's rights, there are people working to turn back the clock—and now many of them have lifetime appointments on the federal bench. Get involved in the public sphere. Push for change. https://t.co/ldHJeAHEkz
# -----
# 1128048937149972480
# I'm on @Columbia's beautiful campus tonight for a conversation with President Lee Bollinger. You can watch live here: https://t.co/wGer17JXtK
# -----
# 1128005604176322560
# As this remarkable piece of journalism reminds us, the ordeal for survivors of torture doesn’t end after they are freed. I’m honored to be giving the keynote at a celebration tomorrow of @heartlandhelps’ transformative work to help survivors heal.
# https://t.co/0pgVIwlPH9
# -----
# 1127570199144738816
# Happy Mother's Day! https://t.co/X1OAEKkObQ
# -----

# %%
y = api.GetUserTimeline(screen_name="HillaryClinton", count=20, max_id=935706980643147777, include_rts=False)
y = [_.AsDict() for _ in y]

# %%
for element in y:
    print (element['id'])
    print (element['full_text'])
    print('------')
# Out:
# 933449899487780864
# You go girl! This is important; costs will go up, &amp; powerful companies will get more powerful. We can’t let it slip through the cracks. https://t.co/js4agpzKeS
# ------
# 933107180131282944
# And on top of that, you can’t beat a little book signing wardrobe fun.
#
# https://t.co/K8VldCmTC6 https://t.co/9q9sTlpL3I
# ------
# 933105980484747264
# And being out on the book tour it has been wonderful to hear from so many people about their activism, their courage, &amp; their resilience.
# https://t.co/LhtTwV7N0d
# ------
# 933105682378870784
# Wow. I wasn’t sure how letting my guard down would go...but it’s been cathartic &amp; rewarding. I loved writing this book, &amp; I’m honored to be in such great company on this list!
# https://t.co/rAYpWHzxrJ
# ------
# 932746529475055618
# It’s been almost 2 months since Congress let the program that provides health care for 9 million children expire. Call Congress &amp; tell them to reauthorize CHIP now: 202-224-3121 https://t.co/jk1FhOcMp2
# ------
# 931292276709580802
# It’s true! I want to join your book club to talk about What Happened &amp; what’s happening...sign up! https://t.co/hmWiCrBgsq
# ------
# 931292070312140804
# @BenSPLATT @DearEvanHansen Two friends on a perfect day. Sincerely, me.
# ------
# 931167854828883968
# Good. https://t.co/IqanY3F28F
# ------
# 930540319606747137
# Being your candidate was the honor of a lifetime. Now it's your turn to #runforsomething: https://t.co/ODzNQEossm
# ------
# 930519362158686209
# Looking forward to a great discussion with my friend Dorothy and to a great day @UVA! Tune in:
# https://t.co/L20mjSwhCR https://t.co/02ALVZAAKZ
# ------
# 930082055278428160
# Join me live this morning at 9:45am for an important discussion about child &amp; adolescent mental health, focused on solutions for families &amp; communities. #ChildMindSummit
# https://t.co/317gv59kHQ
# ------
# 929862099446181888
# Proud of you, Becca!
# https://t.co/xAY3yzdf7f https://t.co/lEo1f5eYDq
# ------
# 929749504131289088
# It was a thrill to work on this project with @ElaineWelteroth.  I’m really proud of the result. I hope you enjoy it. https://t.co/MILM8WdvOg
# ------

# %%
type(y[0])
# Out:
# dict

# %%
y[0]['id']
# Out:
# 933449899487780864

# %%
run ./miner.ipynb

# %%
miner = TweetMiner(api, result_limit = 200)

# %%
first_person = "HillaryClinton"
second_person = "Hadiqa_Kiani"

# %%
first = miner.mine_user_tweets(user=first_person)
second   = miner.mine_user_tweets(user=second_person)

# %%
for x in range(5):
    print (first[x]['text'])
    print('------')
# Out:
# This is grotesque. https://t.co/CvFf9rPO2H
# ------
# In the face of extreme abortion bans sweeping the country, we all have to stand up for women's rights.
#
# At noon tomorrow, join @PPAct, @NARAL, @OnwardTogether partner @IndivisibleTeam, and other groups to #StopTheBans.
#
# Find an event near you: https://t.co/pE5pfz5tiA
# ------
# The boy is the second child to have died in CBP custody in the past week. https://t.co/uLJVezJ1SE
# ------
# Watching the mayor’s race in Denver and pulling for @MayorHancock—he’s a proven progressive leader who will work hard for Colorado.
# ------
# In 2019, every day is Endangered Species Day. We have to act now to prevent the loss of 1 million species over the next few decades—losses that would have a profound effect on human beings. https://t.co/lSxGmUVOXL
# ------

# %%
for x in range(5):
    print (second[x]['text'])
    print('------')
# Out:
# On @AAPNews tonight at 11pm! #AapKaySitaray https://t.co/gdOLKTAHoe
# ------
# You may think you know someone but you never really know what they are capable of until life forces you to see the truth. Birds of a feather...
# ------
# I strongly condemn this act of evil. My thoughts &amp; prayers are with the people of Sri Lanka and with all of those who feel threatened and insecure right now - especially with the Christian community as this is their holy day. My heart breaks for the present state of our world...
# ------
# Thank you❤️ https://t.co/UJMSE52dBx
# ------
# @tanfrance love you for being you! ❤️you’re a source of positivity and you represent the diversity people need to see 🙏🏽
# ------

# %% [markdown]
# #### Converting tweets into pandas DF

# %%
# first person
pd.DataFrame(first)
# Out:
#                           created_at          handle  \
# 0     Mon May 20 21:11:11 +0000 2019  HillaryClinton
# 1     Mon May 20 20:36:31 +0000 2019  HillaryClinton
# 2     Mon May 20 19:27:43 +0000 2019  HillaryClinton
# 3     Fri May 17 17:09:14 +0000 2019  HillaryClinton
# 4     Fri May 17 16:22:05 +0000 2019  HillaryClinton
# 5     Fri May 17 15:16:06 +0000 2019  HillaryClinton
# 6     Fri May 17 14:06:55 +0000 2019  HillaryClinton
# 7     Thu May 16 14:14:42 +0000 2019  HillaryClinton
# 8     Wed May 15 17:39:46 +0000 2019  HillaryClinton
# 9     Wed May 15 17:39:46 +0000 2019  HillaryClinton
# 10    Wed May 15 17:39:45 +0000 2019  HillaryClinton
# 11    Wed May 15 14:27:42 +0000 2019  HillaryClinton
# 12    Wed May 15 14:27:09 +0000 2019  HillaryClinton
# 13    Wed May 15 14:23:25 +0000 2019  HillaryClinton
# 14    Tue May 14 15:24:29 +0000 2019  HillaryClinton
# 15    Mon May 13 21:26:39 +0000 2019  HillaryClinton
# 16    Mon May 13 18:34:28 +0000 2019  HillaryClinton
# 17    Sun May 12 13:44:19 +0000 2019  HillaryClinton
# 18    Fri May 10 21:47:22 +0000 2019  HillaryClinton
# 19    Thu May 09 17:12:06 +0000 2019  HillaryClinton
# 20    Thu May 09 16:26:11 +0000 2019  HillaryClinton
# 21    Wed May 08 20:58:24 +0000 2019  HillaryClinton
# 22    Wed May 08 16:19:34 +0000 2019  HillaryClinton
# 23    Wed May 08 15:05:03 +0000 2019  HillaryClinton
# 24    Wed May 08 14:20:23 +0000 2019  HillaryClinton
# 25    Tue May 07 22:01:08 +0000 2019  HillaryClinton
# 26    Tue May 07 18:52:07 +0000 2019  HillaryClinton
# 27    Tue May 07 17:30:59 +0000 2019  HillaryClinton
# 28    Tue May 07 17:30:59 +0000 2019  HillaryClinton
# 29    Tue May 07 14:45:05 +0000 2019  HillaryClinton
# ...                              ...             ...
# 2572  Mon Sep 05 16:38:27 +0000 2016  HillaryClinton
# 2573  Mon Sep 05 14:12:02 +0000 2016  HillaryClinton
# 2574  Sun Sep 04 23:33:39 +0000 2016  HillaryClinton
# 2575  Sun Sep 04 18:40:21 +0000 2016  HillaryClinton
# 2576  Sun Sep 04 18:06:16 +0000 2016  HillaryClinton
# 2577  Sun Sep 04 14:22:01 +0000 2016  HillaryClinton
# 2578  Sat Sep 03 23:04:58 +0000 2016  HillaryClinton
# 2579  Sat Sep 03 21:50:08 +0000 2016  HillaryClinton
# 2580  Sat Sep 03 21:19:33 +0000 2016  HillaryClinton
# 2581  Sat Sep 03 17:06:35 +0000 2016  HillaryClinton
# 2582  Sat Sep 03 14:06:22 +0000 2016  HillaryClinton
# 2583  Sat Sep 03 02:35:32 +0000 2016  HillaryClinton
# 2584  Fri Sep 02 22:12:24 +0000 2016  HillaryClinton
# 2585  Fri Sep 02 20:05:36 +0000 2016  HillaryClinton
# 2586  Fri Sep 02 18:24:50 +0000 2016  HillaryClinton
# 2587  Fri Sep 02 16:10:28 +0000 2016  HillaryClinton
# 2588  Fri Sep 02 14:26:54 +0000 2016  HillaryClinton
# 2589  Fri Sep 02 12:51:23 +0000 2016  HillaryClinton
# 2590  Fri Sep 02 03:06:52 +0000 2016  HillaryClinton
# 2591  Fri Sep 02 01:51:50 +0000 2016  HillaryClinton
# 2592  Fri Sep 02 01:13:10 +0000 2016  HillaryClinton
# 2593  Thu Sep 01 23:06:36 +0000 2016  HillaryClinton
# 2594  Thu Sep 01 22:20:35 +0000 2016  HillaryClinton
# 2595  Thu Sep 01 21:17:49 +0000 2016  HillaryClinton
# 2596  Thu Sep 01 19:44:35 +0000 2016  HillaryClinton
# 2597  Thu Sep 01 17:24:46 +0000 2016  HillaryClinton
# 2598  Thu Sep 01 16:45:27 +0000 2016  HillaryClinton
# 2599  Thu Sep 01 16:25:34 +0000 2016  HillaryClinton
# 2600  Thu Sep 01 16:06:19 +0000 2016  HillaryClinton
# 2601  Thu Sep 01 15:46:22 +0000 2016  HillaryClinton
#
#                        mined_at  retweet_count  \
# 0    2019-05-20 22:33:50.045228           5952
# 1    2019-05-20 22:33:50.045235           2191
# 2    2019-05-20 22:33:50.045236          12337
# 3    2019-05-20 22:33:50.045237            667
# 4    2019-05-20 22:33:50.045238           3522
# 5    2019-05-20 22:33:50.045239           4831
# 6    2019-05-20 22:33:50.045240           3338
# 7    2019-05-20 22:33:50.045241           7773
# 8    2019-05-20 22:33:50.045242           1168
# 9    2019-05-20 22:33:50.045243           1274
# 10   2019-05-20 22:33:50.045245           1576
# 11   2019-05-20 22:33:50.045246           9430
# 12   2019-05-20 22:33:50.045247          11198
# 13   2019-05-20 22:33:50.045248          50988
# 14   2019-05-20 22:33:50.045249           3884
# 15   2019-05-20 22:33:50.045250            992
# 16   2019-05-20 22:33:50.045250           1553
# 17   2019-05-20 22:33:50.045252           3531
# 18   2019-05-20 22:33:50.045252           1500
# 19   2019-05-20 22:33:50.045253          15147
# 20   2019-05-20 22:33:50.045254            485
# 21   2019-05-20 22:33:50.045255            322
# 22   2019-05-20 22:33:50.045256            495
# 23   2019-05-20 22:33:50.045257          12052
# 24   2019-05-20 22:33:50.045258           1722
# 25   2019-05-20 22:33:50.045259           3020
# 26   2019-05-20 22:33:50.045260           4329
# 27   2019-05-20 22:33:50.045261           3374
# 28   2019-05-20 22:33:50.045262           6542
# 29   2019-05-20 22:33:50.045263           2244
# ...                         ...            ...
# 2572 2019-05-20 22:33:53.286610           3464
# 2573 2019-05-20 22:33:53.286612           2706
# 2574 2019-05-20 22:33:53.286613           3994
# 2575 2019-05-20 22:33:53.286614           3925
# 2576 2019-05-20 22:33:53.286615           1804
# 2577 2019-05-20 22:33:53.286616           3069
# 2578 2019-05-20 22:33:53.286617           2250
# 2579 2019-05-20 22:33:53.286618           2049
# 2580 2019-05-20 22:33:53.286619           2210
# 2581 2019-05-20 22:33:53.286620           7370
# 2582 2019-05-20 22:33:53.286621           3342
# 2583 2019-05-20 22:33:53.286623           3510
# 2584 2019-05-20 22:33:53.286624           2566
# 2585 2019-05-20 22:33:53.286625           8867
# 2586 2019-05-20 22:33:53.286626           2249
# 2587 2019-05-20 22:33:53.286627           2300
# 2588 2019-05-20 22:33:53.286628           1677
# 2589 2019-05-20 22:33:53.286629           9775
# 2590 2019-05-20 22:33:53.286630           1960
# 2591 2019-05-20 22:33:53.286631           1539
# 2592 2019-05-20 22:33:53.286632           1679
# 2593 2019-05-20 22:33:53.286633           6593
# 2594 2019-05-20 22:33:53.286635           1371
# 2595 2019-05-20 22:33:53.286636           3383
# 2596 2019-05-20 22:33:53.286637           1086
# 2597 2019-05-20 22:33:53.286638           2517
# 2598 2019-05-20 22:33:53.286639           2473
# 2599 2019-05-20 22:33:53.286640            935
# 2600 2019-05-20 22:33:53.286641           1192
# 2601 2019-05-20 22:33:53.286642            542
#
#                                                    text             tweet_id
# 0            This is grotesque. https://t.co/CvFf9rPO2H  1130581759639396352
# 1     In the face of extreme abortion bans sweeping ...  1130573037420597249
# 2     The boy is the second child to have died in CB...  1130555721416888320
# 3     Watching the mayor’s race in Denver and pullin...  1129433708807770112
# 4     In 2019, every day is Endangered Species Day. ...  1129421840500363264
# 5     More than 200 major corporations, 500 statewid...  1129405238534901761
# 6     As I said in my keynote celebrating the essent...  1129387825252712449
# 7     Grateful to Planned Parenthood for continuing ...  1129027398920491009
# 8     If you want to be inspired every day, I highly...  1128716614990487552
# 9     We’ve raised money to reunite families separat...  1128716614256427008
# 10    Happy two-year anniversary to our @OnwardToget...  1128716613463814145
# 11    None of us should accept a future in which our...  1128668280913387521
# 12    Here's what you can do today to fight back:\n\...  1128668142018924545
# 13    The abortion bans in Alabama, Georgia, Ohio, K...  1128667204164169728
# 14    As I told @Columbia students last night:\n\nFo...  1128320182194192384
# 15    I'm on @Columbia's beautiful campus tonight fo...  1128048937149972480
# 16    As this remarkable piece of journalism reminds...  1128005604176322560
# 17          Happy Mother's Day! https://t.co/X1OAEKkObQ  1127570199144738816
# 18    I’ve dedicated much of my career to improving ...  1126966988432134146
# 19    The FDA approved the very first birth control ...  1126535324753178625
# 20    Thank you to all the students at @dartmouth fo...  1126523769831477248
# 21    I'm excited to join my old friends and colleag...  1126229890876022787
# 22    I'm so sorry to hear of Freia David’s passing....  1126159716533641220
# 23    Six-week abortion bans are effectively total b...  1126140966224707584
# 24    “The work of democracy is about trying to do t...  1126129722868498432
# 25    An American mother today is 50% more likely to...  1125883287690465281
# 26    No one should have their right to vote taken a...  1125835719488999425
# 27    Take a moment today to help. \n\nCall your rep...  1125815304834179078
# 28    Today marks one year since the administration ...  1125815303944929280
# 29    My prayers go out to everyone grieving the tra...  1125773554354724867
# ...                                                 ...                  ...
# 2572  Unions stand up for workers who need someone t...   772836300722434048
# 2573  If you're a fan of weekends, thank a union mem...   772799454806155264
# 2574  There's going to be no one left in Washington ...   772578400208842752
# 2575  Astonishing that the Republican nominee still ...   772504589102899201
# 2576  We have a new @Tumblr! Check out letters to Hi...   772496012611088384
# 2577  "That’s a special thing about Hillary—when the...   772439580691861504
# 2578  Thanks, @POTUS, for reaffirming the law to pro...   772208796928212993
# 2579  Even before his hateful speech this week, Trum...   772189964327084032
# 2580  A reminder as America officially joins the Par...   772182265375952897
# 2581  Our planet's future depends on the decisions w...   772118606582775808
# 2582  Donald Trump's pattern of prejudice and discri...   772073250561986560
# 2583  Donald Trump's plan on immigration has been cl...   771899397437259776
# 2584  America needs leadership in the White House, n...   771833178092933120
# 2585  When Ruline was born in 1913, women couldn't v...   771801270113935360
# 2586  Drug companies should never put profits before...   771775910278291456
# 2587  Trump and his hateful language are affecting o...   771742094985666560
# 2588  The worst part is, Trump's disturbing policies...   771716034093023232
# 2589  As a candidate, Trump has already embarrassed ...   771691993835638784
# 2590  The disastrous Mexico wall trip: a case study ...   771544894741417984
# 2591  So, how did Donald Trump's first swing at dipl...   771526014988062720
# 2592  Turns out, hosting Miss Universe pageants abro...   771516282151792641
# 2593  It took Donald Trump exactly one foreign polic...   771484431219564544
# 2594  If Trump needs help with diplomacy, he could l...   771472849831878657
# 2595  Born Sept. 1, 1933, former TX Gov. Ann Richard...   771457054133321728
# 2596  "There will be no softening whatsoever." —the ...   771433590689267712
# 2597  This choice couldn't be starker. https://t.co/...   771398407877517312
# 2598  "Trump, the self-proclaimed tough negotiator, ...   771388511752716289
# 2599  "He’s causing nations to wonder if we’ll actua...   771383506840748032
# 2600  "I'm so sick and tired of people like Trump......   771378663489204224
# 2601  Tune in now to watch @JoeBiden hit the trail f...   771373643066544129
#
# [2602 rows x 6 columns]

# %% [markdown]
# # Create the training data
#
# ### 1. Mine first person's tweets
# ### 2. Create a tweet dataframe
# ### 3. Mine Second person's tweets
# ### 4. Append results to our dataframe

# %%
# 1
miner = TweetMiner(api, result_limit=200)
first_tweets = miner.mine_user_tweets(first_person, max_pages=14)

# %%
# 2
first_df = pd.DataFrame(first_tweets)
first_df.shape
# Out:
# (2227, 6)

# %%
# 3
second_tweets = miner.mine_user_tweets(second_person, max_pages=14)

# %%
second_df = pd.DataFrame(second_tweets)
second_df.shape
# Out:
# (1596, 6)

# %%
# 4
tweets = pd.concat([first_df, second_df], axis =0)
tweets.shape
# Out:
# (3823, 6)

# %% [markdown]
# # Machine Learning

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import Counter

#using the Tf_id_Vectorizer to find ngrams for us
vect = TfidfVectorizer(ngram_range=(2,5), stop_words='english')

#Pulls all of first person tweet's text into one giant string
summaries = "".join(first_df['text'])
ngrams_summaries = vect.build_analyzer()(summaries)

Counter(ngrams_summaries).most_common(20)
# Out:
# [('donald trump', 113),
#  ('https ttgeqxnqym', 81),
#  ('hillary https', 65),
#  ('make sure', 61),
#  ('vote https', 59),
#  ('ttgeqxnqym https', 47),
#  ('debatenight https', 47),
#  ('https ttgeqxnqym https', 47),
#  ('https 3tkj4h68kz', 44),
#  ('health care', 43),
#  ('human rights', 33),
#  ('hillary clinton', 33),
#  ('3tkj4h68kz https', 32),
#  ('https 3tkj4h68kz https', 32),
#  ('potus https', 28),
#  ('trump https', 27),
#  ('today https', 25),
#  ('president https', 25),
#  ('debate https', 25),
#  ('https jfd3cxld1s', 24)]

# %%
#using the Tf_id_Vectorizer to find ngrams for us
vect = TfidfVectorizer(ngram_range=(2,5), stop_words='english')

#Pulls all of first person tweet's text into one giant string
summaries = "".join(second_df['text'])
ngrams_summaries = vect.build_analyzer()(summaries)

Counter(ngrams_summaries).most_common(20)
# Out:
# [('thank https', 54),
#  ('god bless', 40),
#  ('allah bless', 34),
#  ('bless https', 34),
#  ('god bless https', 15),
#  ('thank thank', 13),
#  ('lt https', 12),
#  ('thank god', 11),
#  ('thank allah', 11),
#  ('eid mubarak', 11),
#  ('happy birthday', 10),
#  ('aw thank', 10),
#  ('mubarak https', 10),
#  ('thank god bless', 10),
#  ('thank allah bless', 10),
#  ('thank love', 9),
#  ('love https', 9),
#  ('thank thank https', 9),
#  ('allah bless https', 9),
#  ('means lot', 8)]

# %% [markdown]
# # Processing the tweets and building a model
# #### Vectorizing input text data.
# #### Intializing a model.
# #### Grid Searching for optimal hyperparameters.
# #### Training and fitting optimized model.
# #### Evaluating the performance of the model.

# %%
#cleaning text data using textacy
from textacy.preprocess import preprocess_text

tweet_text = tweets['text'].values
print (tweet_text[1:8])
# Out:
# ["In the face of extreme abortion bans sweeping the country, we all have to stand up for women's rights. \n\nAt noon tomorrow, join @PPAct, @NARAL, @OnwardTogether partner @IndivisibleTeam, and other groups to #StopTheBans. \n\nFind an event near you: https://t.co/pE5pfz5tiA"
#  'The boy is the second child to have died in CBP custody in the past week. https://t.co/uLJVezJ1SE'
#  'Watching the mayor’s race in Denver and pulling for @MayorHancock—he’s a proven progressive leader who will work hard for Colorado.'
#  'In 2019, every day is Endangered Species Day. We have to act now to prevent the loss of 1 million species over the next few decades—losses that would have a profound effect on human beings. https://t.co/lSxGmUVOXL'
#  'More than 200 major corporations, 500 statewide and local organizations, a bipartisan consensus in Congress, and 70% of Americans support legislation protecting LGBTQ people from discrimination. \n\nI am proud to stand with them and the other @HRC to support the #EqualityAct.'
#  'As I said in my keynote celebrating the essential work of @heartlandhelps: We have to affirm that torture, physical and psychological, is wrong and will not be tolerated—whether it happens in a prison in Syria or in a cage on our southern border. https://t.co/s8MVpdzgwf'
#  'Grateful to Planned Parenthood for continuing to provide essential services in Alabama and elsewhere while helping to fight the state legislative bans on women’s human and constitutional rights. https://t.co/oMgHvgaP0d']

# %%
clean_text = [preprocess_text(x,  lowercase=True, no_urls=True, no_emails=True, no_phone_numbers=True, no_currency_symbols=True,
                              no_punct=True, no_accents=True)
              for x in tweet_text]
print (clean_text[1:8])
# Out:
# ['in the face of extreme abortion bans sweeping the country we all have to stand up for women s rights at noon tomorrow join ppact naral onwardtogether partner indivisibleteam and other groups to stopthebans find an event near you url', 'the boy is the second child to have died in cbp custody in the past week url', 'watching the mayor s race in denver and pulling for mayorhancock he s a proven progressive leader who will work hard for colorado', 'in 2019 every day is endangered species day we have to act now to prevent the loss of 1 million species over the next few decades losses that would have a profound effect on human beings url', 'more than 200 major corporations 500 statewide and local organizations a bipartisan consensus in congress and 70 of americans support legislation protecting lgbtq people from discrimination i am proud to stand with them and the other hrc to support the equalityact', 'as i said in my keynote celebrating the essential work of heartlandhelps we have to affirm that torture physical and psychological is wrong and will not be tolerated whether it happens in a prison in syria or in a cage on our southern border url', 'grateful to planned parenthood for continuing to provide essential services in alabama and elsewhere while helping to fight the state legislative bans on women s human and constitutional rights url']

# %%
# creating target
y = tweets['handle'].map(lambda x: 1 if x == first_person else 0).values
print (max(pd.Series(y).value_counts(normalize=True)))
# Out:
# 0.582526811404656

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

# %%
# Vectorizing using TF-IDF Vectorizer and creating X matrix
tfv = TfidfVectorizer(ngram_range=(2,4), max_features=2000)
X = tfv.fit_transform(clean_text).todense()
print (X.shape)
# Out:
# (3823, 2000)

# %%
LR = LogisticRegression()
params = {'penalty': ['l1', 'l2'], 'C':np.logspace(-5,0,100)}
#Grid searching to find optimal parameters for Logistic Regression
gs = GridSearchCV(LR, param_grid=params, cv=10, verbose=1)
gs.fit(X, y)
# Out:
# Fitting 10 folds for each of 200 candidates, totalling 2000 fits
# [Parallel(n_jobs=1)]: Done 2000 out of 2000 | elapsed:  1.0min finished
# GridSearchCV(cv=10, error_score='raise',
#        estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'penalty': ['l1', 'l2'], 'C': array([1.00000e-05, 1.12332e-05, ..., 8.90215e-01, 1.00000e+00])},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=1)

# %%
print (gs.best_params_)
print (gs.best_score_)
# Out:
# {'C': 1.0, 'penalty': 'l2'}
# 0.9000784724038713

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(LogisticRegression(), X, y, cv=10)

print (accuracies.mean())
print (1-y.mean())
# Out:
# 0.9000726894873518
# 0.417473188595344
